# %%
import pandas as pd
import numpy as numpy

# %% [markdown]
# As Jupyter Notebook didn't work on my laptop I am using google collab notebook.

# %% [markdown]
# Uploading the job-market file to the notebook.

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-6ea85106-ea4f-437c-bbda-38366862750c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6ea85106-ea4f-437c-bbda-38366862750c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# Q1. Loading the dataset using pandas.

# %%
import io
df = pd.read_csv(io.BytesIO(uploaded['job-market(1).csv']))

# %%
num_rows, num_cols = df.shape
print(f"The Dataset consists of: {num_rows} rows and {num_cols} columns")
# Out:
# The Dataset consists of: 40789 rows and 13 columns

# %% [markdown]
# Q2. Visualise the top 10 first rows

# %%
df.head(10)
# Out:
#            Id                                              Title  \
# 0  37404348.0                           Casual Stock Replenisher
# 1  37404337.0                           Casual Stock Replenisher
# 2  37404356.0  RETAIL SALES SUPERSTARS and STYLISTS Wanted - ...
# 3  37404330.0                              Team member - Belrose
# 4  37404308.0  Business Banking Contact Centre Specialist, Ni...
# 5  37404307.0  Business Banking Contact Centre Specialist, Ni...
# 6  37404355.0               Casual Café All-rounder in Semaphore
# 7  37404350.0           Casual Café All-rounder in Woolloongabba
# 8  37404301.0                                       Telemarketer
# 9  37404286.0                       Casual Dish Hand in Brighton
#
#                                           Company                      Date  \
# 0                                     Aldi Stores  2018-10-07T00:00:00.000Z
# 1                                     Aldi Stores  2018-10-07T00:00:00.000Z
# ...

# %% [markdown]
# Q3. Fix the columns datatypes

# %%
df.dtypes
# Out:
# Id                   float64
# Title                 object
# Company               object
# Date                  object
# Location              object
# Area                  object
# Classification        object
# SubClassification     object
# Requirement           object
# FullDescription       object
# LowestSalary         float64
# HighestSalary        float64
# JobType               object
# dtype: object

# %% [markdown]
# Now, we need to convert the datatype of the Date column.

# %%
df['Date'] = pd.to_datetime(df['Date'])
df['Date'] = df['Date'].dt.tz_localize(None)

# %%
df.dtypes
# Out:
# Id                          float64
# Title                        object
# Company                      object
# Date                 datetime64[ns]
# Location                     object
# Area                         object
# Classification               object
# SubClassification            object
# Requirement                  object
# FullDescription              object
# LowestSalary                float64
# HighestSalary               float64
# JobType                      object
# dtype: object

# %% [markdown]
# Q4. Aggregate existing columns into new column.

# %%
df = df.assign(AverageSalary = (df["LowestSalary"] + df["HighestSalary"])/2)

df.head(10)
# Out:
#            Id                                              Title  \
# 0  37404348.0                           Casual Stock Replenisher
# 1  37404337.0                           Casual Stock Replenisher
# 2  37404356.0  RETAIL SALES SUPERSTARS and STYLISTS Wanted - ...
# 3  37404330.0                              Team member - Belrose
# 4  37404308.0  Business Banking Contact Centre Specialist, Ni...
# 5  37404307.0  Business Banking Contact Centre Specialist, Ni...
# 6  37404355.0               Casual Café All-rounder in Semaphore
# 7  37404350.0           Casual Café All-rounder in Woolloongabba
# 8  37404301.0                                       Telemarketer
# 9  37404286.0                       Casual Dish Hand in Brighton
#
#                                           Company       Date  \
# 0                                     Aldi Stores 2018-10-07
# 1                                     Aldi Stores 2018-10-07
# 2                             LB Creative Pty Ltd 2018-10-07
# ...
